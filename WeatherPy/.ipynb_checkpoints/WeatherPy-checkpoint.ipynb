# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?q=east london'+'&appid='+weather_api_key
weather_response = requests.get(url)
weather_json = weather_response.json()

# %%
#Prepare list to hold retruned api call value
lat = []
lng = []
temp = []
humidity =[]
clouds = []
wind = []
max_temp = []
cities_ls = []
country = []
date = []
cityid = []
#For each city generataed in the cities list, make an API call.
for i in range(len(cities)):
    url = 'http://api.openweathermap.org/data/2.5/weather?q='+cities[i]+'&appid='+weather_api_key
    weather_response = requests.get(url)
    weather_json = weather_response.json()
    try:
        lat.append(weather_json['coord']['lat'])
        lng.append(weather_json['coord']['lon'])
        temp.append(weather_json['main']['temp'])
        humidity.append(weather_json['main']['humidity'])
        clouds.append(weather_json['clouds']['all'])
        wind.append(weather_json['wind']['speed'])
        max_temp.append(weather_json['main']['temp_max'])
        cities_ls.append(weather_json['name'])
        country.append(weather_json['sys']['country'])
        date.append(weather_json['dt'])
        cityid.append(i)
        print(f"Processing Record {i} | {cities[i]}")
    except:
        print("City Data doesn't exist")
        
weather_dict = {
    "City ID":cityid,
    "City": cities_ls,
    "Lat": lat,
    "Lng": lng,    
    "Max Temp": max_temp,
    "Humidity": humidity,  
    "Cloudiness": clouds,
    "Wind Speed":wind,
    "Country": country,
    "Date": date
}
# Out:
# Processing Record 0 | punta arenas
# Processing Record 1 | jamestown
# Processing Record 2 | atuona
# Processing Record 3 | katsuura
# Processing Record 4 | dhidhdhoo
# Processing Record 5 | new norfolk
# Processing Record 6 | kaitangata
# Processing Record 7 | rikitea
# Processing Record 8 | troitsko-pechorsk
# Processing Record 9 | avarua
# Processing Record 10 | longyearbyen
# Processing Record 11 | yellowknife
# Processing Record 12 | hervey bay
# Processing Record 13 | bluff
# Processing Record 14 | lebu
# Processing Record 15 | san juan del rio
# Processing Record 16 | mount isa
# City Data doesn't exist
# Processing Record 18 | ushuaia
# Processing Record 19 | qaanaaq
# Processing Record 20 | cururupu
# Processing Record 21 | tiquisio
# City Data doesn't exist
# Processing Record 23 | mataura
# Processing Record 24 | kapaa
# Processing Record 25 | verbivka
# Processing Record 26 | yar-sale
# Processing Record 27 | port alfred
# City Data doesn't exist
# Processing Record 29 | amga
# Processing Record 30 | cayenne
# Processing Record 31 | hithadhoo
# Processing Record 32 | berlevag
# Processing Record 33 | chokurdakh
# City Data doesn't exist
# Processing Record 35 | barrow
# Processing Record 36 | thompson
# Processing Record 37 | khatanga
# Processing Record 38 | ustye
# Processing Record 39 | victoria
# Processing Record 40 | albany
# Processing Record 41 | dunedin
# Processing Record 42 | sri aman
# Processing Record 43 | chifeng
# Processing Record 44 | norman wells
# Processing Record 45 | kindersley
# Processing Record 46 | setermoen
# Processing Record 47 | lundazi
# Processing Record 48 | voh
# Processing Record 49 | sault sainte marie
# Processing Record 50 | port hardy
# Processing Record 51 | hobart
# Processing Record 52 | sitka
# Processing Record 53 | mahebourg
# Processing Record 54 | kailua
# City Data doesn't exist
# City Data doesn't exist
# Processing Record 57 | moyamba
# Processing Record 58 | arraial do cabo
# Processing Record 59 | dubbo
# Processing Record 60 | khandyga
# Processing Record 61 | santa rosa
# Processing Record 62 | nanortalik
# Processing Record 63 | havelock
# Processing Record 64 | bredasdorp
# Processing Record 65 | vila
# Processing Record 66 | port elizabeth
# Processing Record 67 | garissa
# Processing Record 68 | hermanus
# Processing Record 69 | meulaboh
# Processing Record 70 | cape town
# Processing Record 71 | fonte boa
# Processing Record 72 | kodiak
# Processing Record 73 | kirando
# Processing Record 74 | asyut
# Processing Record 75 | rockland
# Processing Record 76 | derbent
# Processing Record 77 | stanisic
# Processing Record 78 | bambous virieux
# Processing Record 79 | castro
# Processing Record 80 | kavaratti
# Processing Record 81 | westport
# Processing Record 82 | saldanha
# Processing Record 83 | lompoc
# Processing Record 84 | kutum
# Processing Record 85 | severo-kurilsk
# Processing Record 86 | margate
# Processing Record 87 | upernavik
# City Data doesn't exist
# Processing Record 89 | cherskiy
# Processing Record 90 | nikolskoye
# Processing Record 91 | debre sina
# Processing Record 92 | bandarbeyla
# Processing Record 93 | progreso
# Processing Record 94 | abbeville
# Processing Record 95 | busselton
# Processing Record 96 | slave lake
# Processing Record 97 | yamada
# Processing Record 98 | esperance
# Processing Record 99 | vaini
# Processing Record 100 | vitim
# Processing Record 101 | east london
# Processing Record 102 | awbari
# Processing Record 103 | mana
# Processing Record 104 | saint-philippe
# Processing Record 105 | paamiut
# Processing Record 106 | nouadhibou
# Processing Record 107 | faanui
# Processing Record 108 | tasiilaq
# Processing Record 109 | sabang
# Processing Record 110 | dingle
# Processing Record 111 | ust-omchug
# Processing Record 112 | warrington
# Processing Record 113 | fairbanks
# City Data doesn't exist
# Processing Record 115 | bethel
# Processing Record 116 | manica
# Processing Record 117 | sibolga
# Processing Record 118 | abu samrah
# Processing Record 119 | santa isabel do rio negro
# Processing Record 120 | airai
# Processing Record 121 | prado
# Processing Record 122 | hilo
# Processing Record 123 | batticaloa
# Processing Record 124 | eyl
# Processing Record 125 | lagoa
# Processing Record 126 | mar del plata
# Processing Record 127 | xanlar
# Processing Record 128 | pochutla
# Processing Record 129 | hofn
# Processing Record 130 | mbanza-ngungu
# Processing Record 131 | hasaki
# Processing Record 132 | georgetown
# Processing Record 133 | kroya
# Processing Record 134 | san francisco
# Processing Record 135 | port lincoln
# Processing Record 136 | batemans bay
# Processing Record 137 | arlit
# Processing Record 138 | hannibal
# Processing Record 139 | burnie
# Processing Record 140 | saskylakh
# City Data doesn't exist
# Processing Record 142 | mitsamiouli
# Processing Record 143 | carutapera
# Processing Record 144 | ondangwa
# Processing Record 145 | ilulissat
# Processing Record 146 | bend
# Processing Record 147 | kontagora
# Processing Record 148 | ola
# Processing Record 149 | odienne
# Processing Record 150 | berdigestyakh
# Processing Record 151 | port blair
# Processing Record 152 | lavrentiya
# Processing Record 153 | comodoro rivadavia
# Processing Record 154 | goderich
# Processing Record 155 | tuatapere
# Processing Record 156 | tolstoy-yurt
# Processing Record 157 | sosnogorsk
# Processing Record 158 | puerto ayora
# Processing Record 159 | henties bay
# Processing Record 160 | hamilton
# City Data doesn't exist
# Processing Record 162 | gore
# Processing Record 163 | jiuquan
# Processing Record 164 | touros
# Processing Record 165 | axim
# Processing Record 166 | olopa
# Processing Record 167 | pisco
# Processing Record 168 | kavieng
# City Data doesn't exist
# Processing Record 170 | hay river
# Processing Record 171 | panaba
# Processing Record 172 | clyde river
# Processing Record 173 | lishui
# Processing Record 174 | bazaliya
# Processing Record 175 | dakar
# Processing Record 176 | san cristobal
# Processing Record 177 | lyubim
# Processing Record 178 | balkanabat
# Processing Record 179 | carnarvon
# Processing Record 180 | zacatecoluca
# Processing Record 181 | coatepec
# Processing Record 182 | praya
# Processing Record 183 | truckee
# Processing Record 184 | ribeira grande
# Processing Record 185 | tougan
# Processing Record 186 | provideniya
# Processing Record 187 | mikhaylov
# Processing Record 188 | bossangoa
# Processing Record 189 | butaritari
# Processing Record 190 | niamey
# Processing Record 191 | kenai
# Processing Record 192 | iqaluit
# Processing Record 193 | flagstaff
# Processing Record 194 | onguday
# Processing Record 195 | byron bay
# Processing Record 196 | pangai
# Processing Record 197 | quatre cocos
# Processing Record 198 | koutsouras
# Processing Record 199 | sudak
# Processing Record 200 | bengkulu
# Processing Record 201 | usvyaty
# Processing Record 202 | saint george
# Processing Record 203 | guerrero negro
# Processing Record 204 | buala
# Processing Record 205 | bintulu
# Processing Record 206 | aksarka
# Processing Record 207 | tuktoyaktuk
# Processing Record 208 | bronkhorstspruit
# Processing Record 209 | krasnoselkup
# Processing Record 210 | broome
# Processing Record 211 | lingao
# Processing Record 212 | bataipora
# Processing Record 213 | dodge city
# Processing Record 214 | araouane
# Processing Record 215 | san quintin
# Processing Record 216 | bichura
# Processing Record 217 | jieshi
# Processing Record 218 | ashland
# Processing Record 219 | miri
# Processing Record 220 | lenger
# Processing Record 221 | petropavlovsk-kamchatskiy
# Processing Record 222 | sao filipe
# Processing Record 223 | baykit
# Processing Record 224 | cabo san lucas
# City Data doesn't exist
# Processing Record 226 | crossford
# Processing Record 227 | kieta
# Processing Record 228 | namatanai
# City Data doesn't exist
# Processing Record 230 | diego de almagro
# Processing Record 231 | vardo
# Processing Record 232 | ovalle
# Processing Record 233 | vozhega
# Processing Record 234 | aripuana
# Processing Record 235 | wajima
# Processing Record 236 | sedona
# Processing Record 237 | saint-pierre
# Processing Record 238 | pierre
# Processing Record 239 | chuy
# Processing Record 240 | isla vista
# Processing Record 241 | trairi
# Processing Record 242 | denpasar
# Processing Record 243 | adrian
# Processing Record 244 | clemson
# Processing Record 245 | luderitz
# Processing Record 246 | kahului
# Processing Record 247 | ingham
# Processing Record 248 | havre-saint-pierre
# City Data doesn't exist
# Processing Record 250 | haines junction
# Processing Record 251 | siocon
# Processing Record 252 | eureka
# Processing Record 253 | sorland
# Processing Record 254 | gobabis
# Processing Record 255 | udachnyy
# Processing Record 256 | rota
# Processing Record 257 | plettenberg bay
# Processing Record 258 | poum
# Processing Record 259 | astara
# Processing Record 260 | savona
# City Data doesn't exist
# Processing Record 262 | yankton
# Processing Record 263 | napier
# Processing Record 264 | cairns
# Processing Record 265 | san antero
# City Data doesn't exist
# Processing Record 267 | ipixuna
# Processing Record 268 | la rioja
# Processing Record 269 | birao
# Processing Record 270 | yinchuan
# Processing Record 271 | vallenar
# Processing Record 272 | emboscada
# Processing Record 273 | pangoa
# Processing Record 274 | kawalu
# Processing Record 275 | kungurtug
# City Data doesn't exist
# Processing Record 277 | ponta do sol
# Processing Record 278 | peace river
# Processing Record 279 | itacare
# Processing Record 280 | torbay
# Processing Record 281 | hit
# Processing Record 282 | omboue
# Processing Record 283 | dunda
# Processing Record 284 | zarubino
# Processing Record 285 | sebeta
# Processing Record 286 | tessalit
# Processing Record 287 | ca mau
# Processing Record 288 | khandbari
# Processing Record 289 | portland
# Processing Record 290 | charagua
# Processing Record 291 | roald
# Processing Record 292 | xichang
# Processing Record 293 | tiksi
# Processing Record 294 | gravdal
# Processing Record 295 | dawson creek
# Processing Record 296 | srivardhan
# Processing Record 297 | zaoyang
# Processing Record 298 | sao joao da barra
# Processing Record 299 | la ronge
# Processing Record 300 | gasa
# City Data doesn't exist
# City Data doesn't exist
# Processing Record 303 | antofagasta
# Processing Record 304 | ambilobe
# Processing Record 305 | fortuna
# Processing Record 306 | khashuri
# Processing Record 307 | mogadishu
# Processing Record 308 | bima
# Processing Record 309 | tatawin
# Processing Record 310 | north bend
# Processing Record 311 | komsomolskiy
# Processing Record 312 | nome
# Processing Record 313 | kristianstad
# Processing Record 314 | empalme
# Processing Record 315 | narsaq
# Processing Record 316 | hami
# Processing Record 317 | geraldton
# Processing Record 318 | mandapam
# Processing Record 319 | sioux lookout
# Processing Record 320 | pevek
# Processing Record 321 | oranjemund
# Processing Record 322 | jimma
# Processing Record 323 | russell
# Processing Record 324 | college
# Processing Record 325 | port hawkesbury
# Processing Record 326 | sura
# City Data doesn't exist
# Processing Record 328 | long xuyen
# Processing Record 329 | tautira
# Processing Record 330 | glenwood springs
# Processing Record 331 | egvekinot
# Processing Record 332 | ambon
# Processing Record 333 | alta floresta
# Processing Record 334 | cidreira
# Processing Record 335 | port macquarie
# Processing Record 336 | bouar
# Processing Record 337 | caravelas
# City Data doesn't exist
# City Data doesn't exist
# City Data doesn't exist
# Processing Record 341 | monteagudo
# Processing Record 342 | petatlan
# Processing Record 343 | seoul
# Processing Record 344 | flin flon
# Processing Record 345 | leningradskiy
# City Data doesn't exist
# Processing Record 347 | te anau
# Processing Record 348 | selma
# Processing Record 349 | nishihara
# Processing Record 350 | teguise
# Processing Record 351 | mokhsogollokh
# Processing Record 352 | nemuro
# Processing Record 353 | zhengjiatun
# Processing Record 354 | catamarca
# Processing Record 355 | rocha
# Processing Record 356 | balagansk
# Processing Record 357 | la romana
# Processing Record 358 | ponta delgada
# Processing Record 359 | zhezkazgan
# Processing Record 360 | zyryanka
# Processing Record 361 | dikson
# Processing Record 362 | fez
# Processing Record 363 | broken hill
# Processing Record 364 | jinchang
# Processing Record 365 | mazagao
# Processing Record 366 | mizdah
# Processing Record 367 | grand gaube
# Processing Record 368 | podporozhye
# Processing Record 369 | kalmunai
# City Data doesn't exist
# Processing Record 371 | kruisfontein
# Processing Record 372 | tongren
# Processing Record 373 | maragogi
# Processing Record 374 | aklavik
# Processing Record 375 | kletskaya
# Processing Record 376 | jagannathpur
# Processing Record 377 | sao gabriel da cachoeira
# Processing Record 378 | nguruka
# Processing Record 379 | talnakh
# Processing Record 380 | andenes
# Processing Record 381 | ostersund
# Processing Record 382 | daru
# Processing Record 383 | yulara
# Processing Record 384 | imbituba
# City Data doesn't exist
# Processing Record 386 | tazovskiy
# Processing Record 387 | cockburn town
# Processing Record 388 | monticello
# Processing Record 389 | coahuayana
# Processing Record 390 | terrace
# Processing Record 391 | kedrovyy
# City Data doesn't exist
# Processing Record 393 | san patricio
# Processing Record 394 | codrington
# Processing Record 395 | bilma
# Processing Record 396 | bilibino
# Processing Record 397 | wanning
# Processing Record 398 | merauke
# Processing Record 399 | dubovskoye
# Processing Record 400 | necochea
# Processing Record 401 | muisne
# Processing Record 402 | damnagar
# Processing Record 403 | montepuez
# Processing Record 404 | rawson
# Processing Record 405 | vieste
# City Data doesn't exist
# Processing Record 407 | gaozhou
# Processing Record 408 | zeya
# Processing Record 409 | pekan
# Processing Record 410 | bowen
# Processing Record 411 | matara
# Processing Record 412 | bonthe
# Processing Record 413 | kaeo
# Processing Record 414 | thinadhoo
# Processing Record 415 | emba
# Processing Record 416 | ostrovnoy
# Processing Record 417 | dong hoi
# Processing Record 418 | newala
# Processing Record 419 | iskateley
# Processing Record 420 | chenghai
# City Data doesn't exist
# Processing Record 422 | ketchikan
# Processing Record 423 | chepen
# Processing Record 424 | tallahassee
# Processing Record 425 | nha trang
# Processing Record 426 | korsakov
# Processing Record 427 | bryant
# Processing Record 428 | champerico
# Processing Record 429 | kloulklubed
# Processing Record 430 | cap-aux-meules
# Processing Record 431 | nuuk
# Processing Record 432 | inuvik
# Processing Record 433 | moree
# Processing Record 434 | riyadh
# Processing Record 435 | escanaba
# Processing Record 436 | panacan
# Processing Record 437 | malgrat de mar
# City Data doesn't exist
# Processing Record 439 | souillac
# Processing Record 440 | jalu
# Processing Record 441 | alofi
# Processing Record 442 | tiznit
# Processing Record 443 | lichuan
# Processing Record 444 | avera
# Processing Record 445 | redlands
# Processing Record 446 | taoudenni
# Processing Record 447 | palu
# Processing Record 448 | jining
# Processing Record 449 | biltine
# Processing Record 450 | sosnovo-ozerskoye
# Processing Record 451 | waingapu
# Processing Record 452 | tucuman
# Processing Record 453 | lar
# Processing Record 454 | clarence town
# Processing Record 455 | kardailovo
# Processing Record 456 | skelleftea
# Processing Record 457 | chapais
# Processing Record 458 | lasa
# Processing Record 459 | susangerd
# Processing Record 460 | macapa
# Processing Record 461 | pangnirtung
# Processing Record 462 | okhotsk
# Processing Record 463 | tadine
# Processing Record 464 | yatou
# Processing Record 465 | asfi
# City Data doesn't exist
# Processing Record 467 | calvinia
# Processing Record 468 | loandjili
# Processing Record 469 | constitucion
# City Data doesn't exist
# Processing Record 471 | sivas
# Processing Record 472 | tongliao
# Processing Record 473 | bahia blanca
# Processing Record 474 | newport
# Processing Record 475 | khani
# Processing Record 476 | swan hill
# Processing Record 477 | shingu
# Processing Record 478 | hualmay
# Processing Record 479 | la libertad
# Processing Record 480 | ulaanbaatar
# City Data doesn't exist
# Processing Record 482 | santiago
# City Data doesn't exist
# Processing Record 484 | olafsvik
# Processing Record 485 | doume
# Processing Record 486 | vostok
# City Data doesn't exist
# Processing Record 488 | bathsheba
# Processing Record 489 | tuskegee
# Processing Record 490 | hambantota
# Processing Record 491 | ancud
# Processing Record 492 | isla mujeres
# Processing Record 493 | viedma
# Processing Record 494 | shenjiamen
# Processing Record 495 | pangkalanbuun
# Processing Record 496 | itaituba
# Processing Record 497 | tarko-sale
# Processing Record 498 | kaohsiung
# Processing Record 499 | venado tuerto
# Processing Record 500 | manta
# Processing Record 501 | kargasok
# Processing Record 502 | cap malheureux
# Processing Record 503 | amalapuram
# City Data doesn't exist
# Processing Record 505 | benghazi
# Processing Record 506 | yenotayevka
# Processing Record 507 | maniitsoq
# Processing Record 508 | tshikapa
# Processing Record 509 | walvis bay
# Processing Record 510 | sept-iles
# Processing Record 511 | gamba
# Processing Record 512 | sao felix do xingu
# Processing Record 513 | beloha
# City Data doesn't exist
# Processing Record 515 | siverek
# City Data doesn't exist
# Processing Record 517 | impruneta
# Processing Record 518 | sokolo
# Processing Record 519 | aksu
# Processing Record 520 | kasiri
# Processing Record 521 | belaya gora
# Processing Record 522 | uruguaiana
# Processing Record 523 | yingkou
# Processing Record 524 | lorengau
# Processing Record 525 | pacific grove
# Processing Record 526 | izumo
# Processing Record 527 | anadyr
# Processing Record 528 | makakilo city
# Processing Record 529 | sharjah
# Processing Record 530 | panzhihua
# Processing Record 531 | maroua
# Processing Record 532 | acapulco
# Processing Record 533 | beringovskiy
# Processing Record 534 | matagami
# Processing Record 535 | hokitika
# City Data doesn't exist
# Processing Record 537 | rio grande
# Processing Record 538 | alihe
# Processing Record 539 | fayetteville
# Processing Record 540 | mantua
# Processing Record 541 | boa vista
# Processing Record 542 | sistranda
# Processing Record 543 | masuda
# Processing Record 544 | salalah
# Processing Record 545 | point pedro
# Processing Record 546 | the valley
# Processing Record 547 | camabatela
# Processing Record 548 | serebryansk
# City Data doesn't exist
# Processing Record 550 | tonantins
# City Data doesn't exist
# Processing Record 552 | torrington
# City Data doesn't exist
# Processing Record 554 | palmer
# Processing Record 555 | tura
# City Data doesn't exist
# Processing Record 557 | syava
# Processing Record 558 | giyani
# Processing Record 559 | porto novo
# Processing Record 560 | korla
# Processing Record 561 | gizo
# Processing Record 562 | belebey
# Processing Record 563 | xocali
# Processing Record 564 | damghan
# Processing Record 565 | katete
# Processing Record 566 | shimoda
# Processing Record 567 | mirabad
# Processing Record 568 | mezica
# Processing Record 569 | det udom
# Processing Record 570 | barrhead
# Processing Record 571 | burns lake
# Processing Record 572 | arica
# Processing Record 573 | laguna
# Processing Record 574 | vila franca do campo
# Processing Record 575 | launceston
# Processing Record 576 | iquitos
# Processing Record 577 | altay
# Processing Record 578 | les cayes
# Processing Record 579 | ginir
# Processing Record 580 | athabasca
# Processing Record 581 | bairiki
# Processing Record 582 | comlosu mare
# Processing Record 583 | namibe
# Processing Record 584 | camacha
# Processing Record 585 | chirongui
# Processing Record 586 | kars
# Processing Record 587 | makokou
# Processing Record 588 | porosozero
# Processing Record 589 | ariquemes
# Processing Record 590 | otjimbingwe
# Processing Record 591 | clearwater
# City Data doesn't exist
# Processing Record 593 | sorong
# Processing Record 594 | torres
# Processing Record 595 | yaan
# Processing Record 596 | san pedro

# %%
#Date column needs to convert to readable format
weather_data = pd.DataFrame(weather_dict)
weather_data['Max Temp'] = (weather_data['Max Temp']-273.15)*9/5+32
weather_data.set_index('City ID',inplace = True)
weather_data.index.name = None
weather_data.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas -53.1500  -70.9167    42.800        93          90
# 1     Jamestown  42.0970  -79.2353    46.004        49           1
# 2        Atuona  -9.8000 -139.0333    78.872        70           2
# 3      Katsuura  35.1333  140.3000    60.800        88          20
# 4     Dhidhdhoo   6.8833   73.1000    84.290        75          95
#
#    Wind Speed Country        Date
# 0        3.09      CL  1619813989
# 1       10.80      US  1619813885
# 2        1.81      PF  1619813916
# 3        5.14      JP  1619813990
# 4        3.27      MV  1619813990

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data.to_csv("Output/city_data.csv", index=False, header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
weather_humidityover100=weather_data.loc[weather_data['Humidity'] >100,:]
weather_humidityover100.count()
# Out:
# City          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# Country       0
# Date          0
# dtype: int64

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Create a function to draw scatter plot for the parameters passing in, and automatcially name and output the png file
def drawscatterplot(lat, max_temp, xlabel, ylabel, title ):
    plt.scatter(lat,max_temp)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.savefig(f"Output/{ylabel}vs{xlabel}.png")
    plt.show()

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
drawscatterplot(weather_data['Lat'],weather_data['Max Temp'],'Latitude','Max Temperature(F)', 'City Latitude vs. Max Temperature (04/30/2021)')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
drawscatterplot(weather_data['Lat'],weather_data['Humidity'],'Latitude','Humidity(%)','City Latitude vs. Humidity (04/30/2021)')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
drawscatterplot(weather_data['Lat'],weather_data['Cloudiness'],'Latitude','Cloudiness(%)','City Latitude vs.Cloudiness (04/30/2021)')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
drawscatterplot(weather_data['Lat'],weather_data['Wind Speed'],'Latitude','Wind Speed','City Latitude vs. Wind Speed (04/30/2021)')

# %% [markdown]
# ## Linear Regression

# %%
# Split data set to nothern hemisphere and southern hemisphere
weather_data_nh = weather_data.loc[weather_data['Lat']>=0,:]
weather_data_sh = weather_data.loc[weather_data['Lat']<0,:]

# %%
# Create a function to draw linear regression for the parameters passing in, and automatcially name and output the png file
def drawlinreg(x, y, xlabel, ylabel, title):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,(6,10),fontsize=15,color="red")
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    print(f"The r value is: {rvalue}")
    h = title.split()[0]
    plt.savefig(f"Output/linearRegression{h}{ylabel}vs{xlabel}.png")
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
drawlinreg(weather_data_nh['Lat'],weather_data_nh['Max Temp'],'Latitude','Max Temp','Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
# Out:
# The r value is: -0.8545617354353378

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
drawlinreg(weather_data_sh['Lat'],weather_data_sh['Max Temp'],'Latitude','Max Temp','Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
# Out:
# The r value is: 0.756149949935743

# %% [markdown]
# #### Analysis for Max Temp vs. Latitude Linear Regression plot:
# * For both nothern and southern hemisphere, there is a strong linear relationship between temparture and latitude, the closer the latitude toward to 0, the higher the tempature is.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
drawlinreg(weather_data_nh['Lat'],weather_data_nh['Humidity'],'Latitude','Humidity(%)','Northern Hemisphere - Humidity(%) vs. Latitude Linear Regression')
# Out:
# The r value is: 0.15512334689791835

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
drawlinreg(weather_data_sh['Lat'],weather_data_sh['Humidity'],'Latitude','Humidity(%)','Southern Hemisphere - Humidity(%) vs. Latitude Linear Regression')
# Out:
# The r value is: 0.18398047370816087

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
drawlinreg(weather_data_nh['Lat'],weather_data_nh['Cloudiness'],'Latitude','Cloudiness(%)','Northern Hemisphere - Cloudiness(%) vs. Latitude Linear Regression')
# Out:
# The r value is: 0.13880059566985098

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
drawlinreg(weather_data_sh['Lat'],weather_data_sh['Cloudiness'],'Latitude','Cloudiness(%)','Southern Hemisphere - Cloudiness(%) vs. Latitude Linear Regression')
# Out:
# The r value is: 0.1931788274072598

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
drawlinreg(weather_data_nh['Lat'],weather_data_nh['Wind Speed'],'Latitude','Wind Speed(mph)','Northern Hemisphere - Wind Speed(mph) vs. Latitude Linear Regression')
# Out:
# The r value is: 0.10649088997227324

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
drawlinreg(weather_data_sh['Lat'],weather_data_sh['Wind Speed'],'Latitude','Wind Speed(mph)','Southern Hemisphere - Wind Speed(mph) vs. Latitude Linear Regression')
# Out:
# The r value is: -0.15520364596230343
