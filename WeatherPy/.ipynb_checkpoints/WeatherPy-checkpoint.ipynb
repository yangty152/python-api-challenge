# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?q=east london'+'&appid='+weather_api_key
weather_response = requests.get(url)
weather_json = weather_response.json()

# %%
## City ID isn't assigned yet

lat = []
lng = []
temp = []
humidity =[]
clouds = []
wind = []
max_temp = []
cities_ls = []
country = []
date = []
cityid = []
for i in range(len(cities)):
    url = 'http://api.openweathermap.org/data/2.5/weather?q='+cities[i]+'&appid='+weather_api_key
    weather_response = requests.get(url)
    weather_json = weather_response.json()
    try:
        lat.append(weather_json['coord']['lat'])
        lng.append(weather_json['coord']['lon'])
        temp.append(weather_json['main']['temp'])
        humidity.append(weather_json['main']['humidity'])
        clouds.append(weather_json['clouds']['all'])
        wind.append(weather_json['wind']['speed'])
        max_temp.append(weather_json['main']['temp_max'])
        cities_ls.append(weather_json['name'])
        country.append(weather_json['sys']['country'])
        date.append(weather_json['dt'])
        cityid.append(i)
        print(f"Processing Record {i} of | {cities[i]}")
    except:
        print("City Data doesn't exist")
        
weather_dict = {
    "City ID":cityid,
    "City": cities_ls,
    "Cloudiness": clouds,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Wind Speed":wind
}
# Out:
# Processing Record 0 of | jamestown
# Processing Record 1 of | asosa
# City Data doesn't exist
# Processing Record 3 of | hobart
# Processing Record 4 of | saint george
# Processing Record 5 of | sherbakul
# Processing Record 6 of | castro
# Processing Record 7 of | sorland
# Processing Record 8 of | esperance
# Processing Record 9 of | barrow
# City Data doesn't exist
# Processing Record 11 of | cape town
# City Data doesn't exist
# Processing Record 13 of | upernavik
# Processing Record 14 of | avarua
# Processing Record 15 of | praia da vitoria
# Processing Record 16 of | torbay
# Processing Record 17 of | jiaojiang
# Processing Record 18 of | aripuana
# Processing Record 19 of | wabash
# City Data doesn't exist
# Processing Record 21 of | port alfred
# Processing Record 22 of | karakol
# Processing Record 23 of | puerto del rosario
# Processing Record 24 of | chuy
# Processing Record 25 of | kargil
# Processing Record 26 of | rikitea
# Processing Record 27 of | ushuaia
# Processing Record 28 of | collie
# Processing Record 29 of | jamame
# Processing Record 30 of | lata
# Processing Record 31 of | ponta do sol
# Processing Record 32 of | huilong
# Processing Record 33 of | victoria
# Processing Record 34 of | san cristobal
# Processing Record 35 of | iqaluit
# Processing Record 36 of | butaritari
# Processing Record 37 of | abu samrah
# Processing Record 38 of | kruisfontein
# Processing Record 39 of | necochea
# Processing Record 40 of | taoudenni
# Processing Record 41 of | mataura
# Processing Record 42 of | ngorongoro
# Processing Record 43 of | rovenki
# Processing Record 44 of | port elizabeth
# Processing Record 45 of | tuktoyaktuk
# Processing Record 46 of | ancud
# Processing Record 47 of | maloy
# Processing Record 48 of | fortuna
# Processing Record 49 of | brokopondo
# Processing Record 50 of | vaini
# Processing Record 51 of | khani
# Processing Record 52 of | alyangula
# City Data doesn't exist
# Processing Record 54 of | harer
# Processing Record 55 of | portland
# Processing Record 56 of | mount gambier
# Processing Record 57 of | deputatskiy
# Processing Record 58 of | zyryanka
# Processing Record 59 of | punta arenas
# City Data doesn't exist
# Processing Record 61 of | bandarbeyla
# Processing Record 62 of | caramay
# Processing Record 63 of | makakilo city
# Processing Record 64 of | cherskiy
# Processing Record 65 of | ribeira grande
# Processing Record 66 of | hilo
# Processing Record 67 of | uyemskiy
# Processing Record 68 of | mayumba
# Processing Record 69 of | touros
# Processing Record 70 of | baoshan
# Processing Record 71 of | sur
# Processing Record 72 of | atuona
# Processing Record 73 of | fatehpur
# Processing Record 74 of | tessalit
# Processing Record 75 of | sibu
# Processing Record 76 of | culebra
# Processing Record 77 of | kulhudhuffushi
# Processing Record 78 of | skovorodino
# Processing Record 79 of | hermanus
# Processing Record 80 of | qaanaaq
# Processing Record 81 of | skibbereen
# Processing Record 82 of | saint-pierre
# Processing Record 83 of | ngawen
# Processing Record 84 of | dwarka
# Processing Record 85 of | clyde river
# Processing Record 86 of | santa vitoria do palmar
# Processing Record 87 of | provideniya
# Processing Record 88 of | sawakin
# Processing Record 89 of | cabo san lucas
# Processing Record 90 of | pisco
# Processing Record 91 of | oistins
# Processing Record 92 of | vao
# Processing Record 93 of | busselton
# Processing Record 94 of | valparaiso
# Processing Record 95 of | grand gaube
# Processing Record 96 of | almenara
# Processing Record 97 of | bilibino
# Processing Record 98 of | yagodnoye
# Processing Record 99 of | xinzhou
# Processing Record 100 of | arraial do cabo
# Processing Record 101 of | mercedes
# Processing Record 102 of | leningradskiy
# Processing Record 103 of | lima
# City Data doesn't exist
# Processing Record 105 of | nikolskoye
# City Data doesn't exist
# Processing Record 107 of | chokwe
# Processing Record 108 of | kapaa
# Processing Record 109 of | ilanskiy
# Processing Record 110 of | port-cartier
# Processing Record 111 of | camacha
# Processing Record 112 of | tiksi
# Processing Record 113 of | ngunguru
# Processing Record 114 of | albany
# Processing Record 115 of | new norfolk
# Processing Record 116 of | riyadh
# Processing Record 117 of | lebu
# Processing Record 118 of | kodiak
# Processing Record 119 of | lavara
# Processing Record 120 of | kieta
# Processing Record 121 of | podporozhye
# Processing Record 122 of | ilulissat
# Processing Record 123 of | puerto ayora
# Processing Record 124 of | taltal
# Processing Record 125 of | hithadhoo
# Processing Record 126 of | geraldton
# Processing Record 127 of | east london
# Processing Record 128 of | dalianwan
# Processing Record 129 of | dikson
# Processing Record 130 of | kaitangata
# Processing Record 131 of | rorvik
# Processing Record 132 of | sechura
# Processing Record 133 of | souillac
# Processing Record 134 of | antofagasta
# City Data doesn't exist
# Processing Record 136 of | cayenne
# Processing Record 137 of | hamilton
# Processing Record 138 of | san-pedro
# Processing Record 139 of | tezu
# Processing Record 140 of | hobyo
# Processing Record 141 of | gladstone
# Processing Record 142 of | sawtell
# Processing Record 143 of | zheleznodorozhnyy
# Processing Record 144 of | mahebourg
# Processing Record 145 of | christchurch
# Processing Record 146 of | vanavara
# Processing Record 147 of | mafra
# Processing Record 148 of | pevek
# Processing Record 149 of | mecca
# Processing Record 150 of | teyateyaneng
# Processing Record 151 of | basoko
# City Data doesn't exist
# Processing Record 153 of | grindavik
# Processing Record 154 of | nekhayevskiy
# Processing Record 155 of | riachao
# Processing Record 156 of | darlowo
# Processing Record 157 of | broome
# Processing Record 158 of | tateyama
# City Data doesn't exist
# Processing Record 160 of | wewak
# Processing Record 161 of | requena
# Processing Record 162 of | traverse city
# Processing Record 163 of | dire
# Processing Record 164 of | cidreira
# Processing Record 165 of | longyearbyen
# Processing Record 166 of | benguela
# Processing Record 167 of | flinders
# Processing Record 168 of | olafsvik
# Processing Record 169 of | bengkulu
# Processing Record 170 of | nanortalik
# Processing Record 171 of | yar-sale
# Processing Record 172 of | port macquarie
# Processing Record 173 of | prince rupert
# Processing Record 174 of | bethel
# Processing Record 175 of | bluff
# Processing Record 176 of | tasiilaq
# Processing Record 177 of | dezhou
# Processing Record 178 of | carnarvon
# Processing Record 179 of | pineville
# City Data doesn't exist
# Processing Record 181 of | katsuura
# Processing Record 182 of | rantepao
# Processing Record 183 of | nouadhibou
# City Data doesn't exist
# Processing Record 185 of | kilindoni
# Processing Record 186 of | naze
# Processing Record 187 of | anito
# Processing Record 188 of | bowen
# Processing Record 189 of | petropavlovsk-kamchatskiy
# Processing Record 190 of | bow island
# Processing Record 191 of | tongren
# Processing Record 192 of | mar del plata
# Processing Record 193 of | puerto el triunfo
# Processing Record 194 of | bathsheba
# Processing Record 195 of | shimoda
# Processing Record 196 of | georgetown
# Processing Record 197 of | kathmandu
# Processing Record 198 of | khatanga
# Processing Record 199 of | ucluelet
# Processing Record 200 of | pokrovskoye
# Processing Record 201 of | saint-georges
# Processing Record 202 of | tucuman
# City Data doesn't exist
# Processing Record 204 of | port-gentil
# Processing Record 205 of | samarai
# Processing Record 206 of | nishihara
# Processing Record 207 of | puri
# City Data doesn't exist
# Processing Record 209 of | zhigansk
# Processing Record 210 of | codrington
# Processing Record 211 of | qingdao
# Processing Record 212 of | banda aceh
# Processing Record 213 of | gazanjyk
# Processing Record 214 of | yellowknife
# Processing Record 215 of | opuwo
# Processing Record 216 of | muros
# Processing Record 217 of | severo-kurilsk
# Processing Record 218 of | saint-philippe
# Processing Record 219 of | wenzhou
# Processing Record 220 of | richards bay
# Processing Record 221 of | vila velha
# Processing Record 222 of | brighton
# Processing Record 223 of | college
# Processing Record 224 of | lompoc
# Processing Record 225 of | norman wells
# Processing Record 226 of | mitchell
# Processing Record 227 of | pizarro
# Processing Record 228 of | ahipara
# Processing Record 229 of | chokurdakh
# Processing Record 230 of | rawson
# Processing Record 231 of | chimbote
# Processing Record 232 of | narsaq
# Processing Record 233 of | kaeo
# Processing Record 234 of | salalah
# Processing Record 235 of | qarchi gak
# Processing Record 236 of | oktyabrskoye
# Processing Record 237 of | airai
# Processing Record 238 of | poum
# Processing Record 239 of | svay rieng
# Processing Record 240 of | talcahuano
# City Data doesn't exist
# Processing Record 242 of | bredasdorp
# Processing Record 243 of | jipijapa
# Processing Record 244 of | lorengau
# Processing Record 245 of | lusambo
# Processing Record 246 of | kishi
# Processing Record 247 of | coquimbo
# Processing Record 248 of | willimantic
# Processing Record 249 of | praya
# Processing Record 250 of | mantua
# Processing Record 251 of | bambous virieux
# Processing Record 252 of | adrar
# Processing Record 253 of | thompson
# Processing Record 254 of | kastamonu
# Processing Record 255 of | vestmannaeyjar
# Processing Record 256 of | saskylakh
# Processing Record 257 of | kaputa
# Processing Record 258 of | sulangan
# Processing Record 259 of | kondoa
# Processing Record 260 of | nykoping
# Processing Record 261 of | angoche
# Processing Record 262 of | dickson
# Processing Record 263 of | buraydah
# Processing Record 264 of | kassala
# Processing Record 265 of | talnakh
# Processing Record 266 of | honiara
# Processing Record 267 of | fort saint james
# City Data doesn't exist
# Processing Record 269 of | madang
# Processing Record 270 of | port lincoln
# Processing Record 271 of | tilichiki
# Processing Record 272 of | santa maria da vitoria
# City Data doesn't exist
# Processing Record 274 of | nome
# City Data doesn't exist
# Processing Record 276 of | wana
# Processing Record 277 of | pathein
# City Data doesn't exist
# Processing Record 279 of | beringovskiy
# Processing Record 280 of | puerto baquerizo moreno
# Processing Record 281 of | constitucion
# Processing Record 282 of | yerbogachen
# Processing Record 283 of | kavieng
# Processing Record 284 of | sehithwa
# Processing Record 285 of | tsumeb
# Processing Record 286 of | bubaque
# Processing Record 287 of | puerto madryn
# City Data doesn't exist
# Processing Record 289 of | sumare
# Processing Record 290 of | limon
# Processing Record 291 of | hofn
# Processing Record 292 of | mpika
# Processing Record 293 of | te anau
# Processing Record 294 of | izhmorskiy
# Processing Record 295 of | alofi
# City Data doesn't exist
# Processing Record 297 of | faanui
# Processing Record 298 of | palmer
# Processing Record 299 of | shingu
# Processing Record 300 of | pacific grove
# Processing Record 301 of | west odessa
# Processing Record 302 of | bridgetown
# Processing Record 303 of | zilair
# City Data doesn't exist
# Processing Record 305 of | terrace
# City Data doesn't exist
# Processing Record 307 of | bassar
# Processing Record 308 of | morant bay
# Processing Record 309 of | abaete
# Processing Record 310 of | keffi
# Processing Record 311 of | dunedin
# Processing Record 312 of | maningrida
# Processing Record 313 of | dingle
# Processing Record 314 of | micomeseng
# Processing Record 315 of | abalak
# Processing Record 316 of | sangar
# Processing Record 317 of | kununurra
# Processing Record 318 of | novyy urengoy
# Processing Record 319 of | raga
# Processing Record 320 of | aden
# Processing Record 321 of | nichinan
# Processing Record 322 of | kuala terengganu
# Processing Record 323 of | tigil
# Processing Record 324 of | bainbridge
# Processing Record 325 of | villa union
# Processing Record 326 of | vila franca do campo
# Processing Record 327 of | opochka
# Processing Record 328 of | kolosovka
# Processing Record 329 of | collierville
# Processing Record 330 of | abhar
# City Data doesn't exist
# Processing Record 332 of | russell
# Processing Record 333 of | lagoa
# Processing Record 334 of | comodoro rivadavia
# Processing Record 335 of | waddan
# Processing Record 336 of | moindou
# Processing Record 337 of | sambava
# Processing Record 338 of | hegang
# Processing Record 339 of | koungou
# Processing Record 340 of | mayahi
# Processing Record 341 of | veraval
# City Data doesn't exist
# Processing Record 343 of | bonavista
# Processing Record 344 of | hervey bay
# Processing Record 345 of | urubicha
# Processing Record 346 of | lokosovo
# City Data doesn't exist
# Processing Record 348 of | toccoa
# City Data doesn't exist
# Processing Record 350 of | inuvik
# City Data doesn't exist
# Processing Record 352 of | ostrovnoy
# Processing Record 353 of | vangaindrano
# Processing Record 354 of | miraflores
# Processing Record 355 of | hay river
# Processing Record 356 of | saldanha
# Processing Record 357 of | wuning
# Processing Record 358 of | abha
# Processing Record 359 of | nuristan
# Processing Record 360 of | fort nelson
# Processing Record 361 of | chumikan
# Processing Record 362 of | bairiki
# Processing Record 363 of | port blair
# Processing Record 364 of | tubmanburg
# Processing Record 365 of | mahajanga
# Processing Record 366 of | sitka
# Processing Record 367 of | daud khel
# Processing Record 368 of | hovd
# Processing Record 369 of | muroto
# Processing Record 370 of | isangel
# City Data doesn't exist
# Processing Record 372 of | awbari
# Processing Record 373 of | ushtobe
# Processing Record 374 of | merauke
# Processing Record 375 of | broken hill
# Processing Record 376 of | baykit
# Processing Record 377 of | upata
# Processing Record 378 of | loa janan
# Processing Record 379 of | mae hong son
# Processing Record 380 of | solntsevo
# Processing Record 381 of | kozhva
# Processing Record 382 of | vung tau
# Processing Record 383 of | yulara
# Processing Record 384 of | padang
# City Data doesn't exist
# Processing Record 386 of | sorong
# Processing Record 387 of | sinnamary
# Processing Record 388 of | kandi
# Processing Record 389 of | coihaique
# Processing Record 390 of | goma
# Processing Record 391 of | aklavik
# Processing Record 392 of | maniitsoq
# Processing Record 393 of | severnyy
# Processing Record 394 of | eidfjord
# Processing Record 395 of | klaksvik
# Processing Record 396 of | matadi
# Processing Record 397 of | alice springs
# Processing Record 398 of | teguise
# Processing Record 399 of | masyaf
# Processing Record 400 of | kualakapuas
# Processing Record 401 of | mwanza
# Processing Record 402 of | ayagoz
# Processing Record 403 of | hasaki
# Processing Record 404 of | flin flon
# Processing Record 405 of | ambon
# City Data doesn't exist
# Processing Record 407 of | pedasi
# Processing Record 408 of | san carlos de bariloche
# Processing Record 409 of | buzuluk
# City Data doesn't exist
# Processing Record 411 of | ust-kuyga
# Processing Record 412 of | dongsheng
# City Data doesn't exist
# Processing Record 414 of | walvis bay
# Processing Record 415 of | manono
# Processing Record 416 of | filadelfia
# Processing Record 417 of | pervomayskiy
# Processing Record 418 of | obama
# Processing Record 419 of | pangnirtung
# Processing Record 420 of | seoul
# Processing Record 421 of | bilaspur
# Processing Record 422 of | poquoson
# Processing Record 423 of | gumdag
# Processing Record 424 of | darhan
# Processing Record 425 of | qaqortoq
# Processing Record 426 of | longhua
# Processing Record 427 of | srivardhan
# Processing Record 428 of | pachino
# City Data doesn't exist
# Processing Record 430 of | waingapu
# Processing Record 431 of | margate
# Processing Record 432 of | kijang
# Processing Record 433 of | mabaruma
# Processing Record 434 of | aykhal
# Processing Record 435 of | pangkalanbuun
# Processing Record 436 of | novo aripuana
# Processing Record 437 of | lakatoro
# Processing Record 438 of | san patricio
# Processing Record 439 of | guerrero negro
# Processing Record 440 of | indramayu
# Processing Record 441 of | burnie
# Processing Record 442 of | kyren
# Processing Record 443 of | umm kaddadah
# Processing Record 444 of | yarim
# Processing Record 445 of | chunhuhub
# Processing Record 446 of | moron
# Processing Record 447 of | shelburne
# Processing Record 448 of | san vicente
# Processing Record 449 of | hare bay
# Processing Record 450 of | vardo
# Processing Record 451 of | oranjemund
# Processing Record 452 of | semporna
# Processing Record 453 of | korla
# Processing Record 454 of | laguna
# Processing Record 455 of | kidal
# Processing Record 456 of | iberia
# Processing Record 457 of | fairbanks
# Processing Record 458 of | port hardy
# Processing Record 459 of | sao joao da barra
# Processing Record 460 of | shobara
# City Data doesn't exist
# Processing Record 462 of | mozhaysk
# Processing Record 463 of | roma
# Processing Record 464 of | tura
# Processing Record 465 of | marshalltown
# Processing Record 466 of | carnoustie
# City Data doesn't exist
# Processing Record 468 of | visby
# Processing Record 469 of | souris
# Processing Record 470 of | zhanaozen
# Processing Record 471 of | ust-ishim
# Processing Record 472 of | gimli
# Processing Record 473 of | mujiayingzi
# Processing Record 474 of | kisesa
# Processing Record 475 of | dobsina
# Processing Record 476 of | tocopilla
# Processing Record 477 of | namibe
# Processing Record 478 of | ormara
# Processing Record 479 of | villa carlos paz
# Processing Record 480 of | chernaya kholunitsa
# Processing Record 481 of | the valley
# Processing Record 482 of | marang
# Processing Record 483 of | nelson bay
# Processing Record 484 of | fukue
# Processing Record 485 of | sarangani
# Processing Record 486 of | rock springs
# Processing Record 487 of | bauchi
# Processing Record 488 of | yevsino
# Processing Record 489 of | hambantota
# Processing Record 490 of | mao
# Processing Record 491 of | kamenka
# Processing Record 492 of | amvrosiyivka
# Processing Record 493 of | estelle
# Processing Record 494 of | brae
# Processing Record 495 of | nassjo
# Processing Record 496 of | tignere
# Processing Record 497 of | west wendover
# Processing Record 498 of | khabary
# City Data doesn't exist
# Processing Record 500 of | inhambane
# City Data doesn't exist
# Processing Record 502 of | houma
# Processing Record 503 of | jardim
# Processing Record 504 of | avera
# Processing Record 505 of | amahai
# Processing Record 506 of | port hedland
# Processing Record 507 of | chicaman
# Processing Record 508 of | paranga
# Processing Record 509 of | olustvere
# Processing Record 510 of | waitati
# Processing Record 511 of | havoysund
# Processing Record 512 of | yatou
# Processing Record 513 of | windhoek
# Processing Record 514 of | tuburan
# Processing Record 515 of | zhangye
# Processing Record 516 of | haines junction
# Processing Record 517 of | guhagar
# Processing Record 518 of | redmond
# Processing Record 519 of | pangody
# Processing Record 520 of | sebinkarahisar
# Processing Record 521 of | abu dhabi
# Processing Record 522 of | tambura
# Processing Record 523 of | hami
# Processing Record 524 of | gerede
# Processing Record 525 of | bosaso
# Processing Record 526 of | kitimat
# Processing Record 527 of | fort morgan
# Processing Record 528 of | erenhot
# Processing Record 529 of | sisimiut
# Processing Record 530 of | atar
# City Data doesn't exist
# Processing Record 532 of | wellington
# Processing Record 533 of | sobolevo
# Processing Record 534 of | renfrew
# Processing Record 535 of | nanakuli
# Processing Record 536 of | black diamond
# Processing Record 537 of | lodwar
# Processing Record 538 of | kahului
# Processing Record 539 of | gold coast
# Processing Record 540 of | new ulm
# Processing Record 541 of | gat
# City Data doesn't exist
# Processing Record 543 of | calvinia
# City Data doesn't exist
# Processing Record 545 of | imst
# Processing Record 546 of | hammerfest
# Processing Record 547 of | murgab
# Processing Record 548 of | bitung
# Processing Record 549 of | koumac
# Processing Record 550 of | alberton
# Processing Record 551 of | canarana
# Processing Record 552 of | southbridge
# Processing Record 553 of | okha
# Processing Record 554 of | la ronge
# Processing Record 555 of | matagami
# Processing Record 556 of | eureka
# Processing Record 557 of | tecoanapa
# Processing Record 558 of | peniche
# Processing Record 559 of | harrisonburg
# Processing Record 560 of | polunochnoye
# Processing Record 561 of | ca mau
# Processing Record 562 of | hudiksvall
# Processing Record 563 of | tevriz
# Processing Record 564 of | tuatapere
# Processing Record 565 of | tarbagatay
# Processing Record 566 of | aquiraz
# Processing Record 567 of | pochutla
# Processing Record 568 of | rocha
# Processing Record 569 of | samfya
# Processing Record 570 of | burley
# Processing Record 571 of | srednekolymsk
# Processing Record 572 of | faya
# Processing Record 573 of | kargasok
# Processing Record 574 of | belvedere marittimo
# Processing Record 575 of | herat
# Processing Record 576 of | kozova
# Processing Record 577 of | lac du bonnet
# Processing Record 578 of | mersing
# Processing Record 579 of | banyuwangi
# Processing Record 580 of | kampong chhnang
# Processing Record 581 of | purranque
# Processing Record 582 of | aksu
# Processing Record 583 of | puerto concordia
# Processing Record 584 of | san jeronimo
# Processing Record 585 of | porto torres
# Processing Record 586 of | luderitz
# Processing Record 587 of | abnub
# Processing Record 588 of | obo
# Processing Record 589 of | pushkino
# Processing Record 590 of | warwick
# Processing Record 591 of | chaozhou
# Processing Record 592 of | guadalupe
# Processing Record 593 of | najran
# Processing Record 594 of | paamiut
# Processing Record 595 of | trairi
# Processing Record 596 of | kalmunai
# Processing Record 597 of | san policarpo
# Processing Record 598 of | san quintin
# Processing Record 599 of | neepawa
# Processing Record 600 of | aswan
# Processing Record 601 of | takab
# Processing Record 602 of | mount isa
# Processing Record 603 of | bebedouro

# %%
#Date column needs to convert to readable format
weather_data = pd.DataFrame(weather_dict)
weather_data['Max Temp'] = (weather_data['Max Temp']-273.15)*9/5+32
weather_data.head()
# Out:
#    City ID          City  Cloudiness Country        Date  Humidity      Lat  \
# 0        0     Jamestown          90      US  1619755274       100  42.0970
# 1        1         Āsosa         100      ET  1619755431        78  10.0667
# 2        3        Hobart          20      AU  1619755431        55 -42.8794
# 3        4  Saint George           1      US  1619755432        17  37.1041
# 4        5    Sherbakul'           0      RU  1619755432        35  54.6316
#
#         Lng  Max Temp  Wind Speed
# 0  -79.2353    46.004        5.66
# 1   34.5333    63.266        1.79
# 2  147.3294    68.000        2.57
# 3 -113.5841    75.992        1.40
# 4   72.3963    51.800        5.00

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data.to_csv("Output/city_data.csv", index=False, header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
weather_humidityover100=weather_data.loc[weather_data['Humidity'] >100,:]
weather_humidityover100
# Out:
# Empty DataFrame
# Columns: [City ID, City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temp, Wind Speed]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
def drawscatterplot(lat, max_temp, xlabel, ylabel, title ):
    plt.scatter(lat,max_temp)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# %%
drawscatterplot(weather_data['Lat'],weather_data['Max Temp'],'Latitude','Max Temperature(F)', 'City Latitude vs. Max Temperature')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
drawscatterplot(weather_data['Lat'],weather_data['Humidity'],'Latitude','Humidity(%)','City Latitude vs. Humidity')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
drawscatterplot(weather_data['Lat'],weather_data['Cloudiness'],'Latitude','Cloudiness(%)','City Latitude vs.Cloudiness')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
drawscatterplot(weather_data['Lat'],weather_data['Wind Speed'],'Latitude','Wind Speed','City Latitude vs. Wind Speed')

# %% [markdown]
# ## Linear Regression

# %%
weather_data_nh = weather_data.loc[weather_data['Lat']>=0,:]
weather_data_sh = weather_data.loc[weather_data['Lat']<0,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
def drawlinreg(x, y, xlabel, ylabel, title):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,(6,10),fontsize=15,color="red")
    plt.title(title)
    print(f"The r-squared is: {rvalue**2}")
    plt.show()

# %%
drawlinreg(weather_data_nh['Lat'],weather_data_nh['Max Temp'],'Latitude','Max Temp','Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
# Out:
# The r-squared is: 0.7806767213690777

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
drawlinreg(weather_data_sh['Lat'],weather_data_sh['Max Temp'],'Latitude','Max Temp','Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
# Out:
# The r-squared is: 0.41044330789022976

# %% [markdown]
# #### Analysis for Max Temp vs. Latitude Linear Regression plot:
# * For both nothern and southern hemisphere, there is a strong linear relationship between temparture and latitude, the closer the latitude toward to 0, the higher the tempature is.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
drawlinreg(weather_data_nh['Lat'],weather_data_nh['Humidity'],'Latitude','Humidity(%)','Northern Hemisphere - Humidity(%) vs. Latitude Linear Regression')
# Out:
# The r-squared is: 0.01577904168785981

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
drawlinreg(weather_data_sh['Lat'],weather_data_sh['Humidity'],'Latitude','Humidity(%)','Southern Hemisphere - Humidity(%) vs. Latitude Linear Regression')
# Out:
# The r-squared is: 0.017890766952019594

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
drawlinreg(weather_data_nh['Lat'],weather_data_nh['Cloudiness'],'Latitude','Cloudiness(%)','Northern Hemisphere - Cloudiness(%) vs. Latitude Linear Regression')
# Out:
# The r-squared is: 0.0015207381439359309

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
drawlinreg(weather_data_sh['Lat'],weather_data_sh['Cloudiness'],'Latitude','Cloudiness(%)','Southern Hemisphere - Cloudiness(%) vs. Latitude Linear Regression')
# Out:
# The r-squared is: 0.04590859812940924

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
drawlinreg(weather_data_nh['Lat'],weather_data_nh['Wind Speed'],'Latitude','Wind Speed(mph)','Northern Hemisphere - Wind Speed(mph) vs. Latitude Linear Regression')
# Out:
# The r-squared is: 0.01976605823553725

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
drawlinreg(weather_data_sh['Lat'],weather_data_sh['Wind Speed'],'Latitude','Wind Speed(mph)','Southern Hemisphere - Wind Speed(mph) vs. Latitude Linear Regression')
# Out:
# The r-squared is: 0.09978840267789982
